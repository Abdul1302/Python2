# %% [markdown]
# # Functions

# %%
name='Muhammad Abdul Rehman'

print(type(name))
# Out:
# <class 'str'>

# %%
name.capitalize()
# Out:
# 'Muhammad abdul rehman'

# %%
name.casefold()
# Out:
# 'muhammad abdul rehman'

# %%
name.center(20,' ')
# Out:
# 'Muhammad Abdul Rehman'

# %%
name='Muhammad Abdul Rehman'
name.upper()
# Out:
# 'MUHAMMAD ABDUL REHMAN'

# %%
name.lower()
# Out:
# 'muhammad abdul rehman'

# %%
name.encode()
# Out:
# b'Muhammad Abdul Rehman'

# %%
name.endswith("Rehman")
# Out:
# True

# %%
name.endswith("Abdul")
# Out:
# False

# %%
para="My name is Abdul Rehman.age is 20"


para.find("is")
# Out:
# 8

# %%
para[3]
# Out:
# 'n'

# %%
para[-7]
# Out:
# 'e'

# %%
len(name)
# Out:
# 21

# %%
name.strip()
# Out:
# 'Muhammad Abdul Rehman'

# %%
name.isalpha()
# Out:
# False

# %%
name.isalnum()
# Out:
# False

# %%
name.isascii()
# Out:
# True

# %%
'-'.join(name)
# Out:
# 'M-u-h-a-m-m-a-d- -A-b-d-u-l- -R-e-h-m-a-n'
